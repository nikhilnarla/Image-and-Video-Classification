# %%
import pandas as pd
import os
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import cv2
import splitfolders
import shutil
from tensorflow.keras.preprocessing.image import img_to_array
import statistics
import numpy as np
from tensorflow.keras.applications import ResNet50, EfficientNetB0, VGG16
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D, BatchNormalization
from tensorflow.keras.losses import CategoricalCrossentropy
from sklearn.metrics import confusion_matrix, classification_report,accuracy_score,f1_score
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Data Exploration and Pre-processing

# %%
# # !pip install opencv-python
# !pip install split-folders
gpus = tf.config.experimental.list_physical_devices('GPU')

# %%
dirpath = '../Data/Sport Images/output'
if os.path.exists(dirpath) and os.path.isdir(dirpath):
    shutil.rmtree(dirpath)

splitfolders.ratio("../Data/Sport Images", output="../Data/Sport Images/output",
    seed=1337, ratio=(.7, .15, .15), group_prefix=None, move=False) # default values
# Out:
# Copying files: 3280 files [00:01, 2862.34 files/s]

# %%
dirs = ['../Data/Sport Images/output/train','../Data/Sport Images/output/val','../Data/Sport Images/output/test']

desired_size = (256, 256)
for dir_path in dirs:
    for subdir in os.listdir(dir_path):
        subdir_path = os.path.join(dir_path, subdir)

        print(subdir_path)
        for filename in os.listdir(subdir_path):
            if filename.endswith('.gif'):
                continue
            img = cv2.imread(os.path.join(subdir_path, filename))

            # Resize image
            resized_img = cv2.resize(img, desired_size)

            # Save resized image
            cv2.imwrite(os.path.join(subdir_path, filename), resized_img)
# Out:
# libpng warning: iCCP: known incorrect sRGB profile
# ../Data/Sport Images/output/train/baseball
# ../Data/Sport Images/output/train/basketball
# libpng warning: iCCP: known incorrect sRGB profile
# ../Data/Sport Images/output/train/volleyball
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile
# ../Data/Sport Images/output/train/fencing
# libpng warning: iCCP: known incorrect sRGB profile
# ../Data/Sport Images/output/train/tennis
# libpng warning: iCCP: known incorrect sRGB profile
# ../Data/Sport Images/output/val/baseball
# ../Data/Sport Images/output/val/basketball
# ../Data/Sport Images/output/val/volleyball
# ../Data/Sport Images/output/val/fencing
# ../Data/Sport Images/output/val/tennis
# ../Data/Sport Images/output/test/baseball
# ../Data/Sport Images/output/test/basketball
# ../Data/Sport Images/output/test/volleyball
# ../Data/Sport Images/output/test/fencing
# ../Data/Sport Images/output/test/tennis
# libpng warning: iCCP: known incorrect sRGB profile
# libpng warning: iCCP: known incorrect sRGB profile

# %%
image_size = (256, 256)
batch = 5
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    '../Data/Sport Images/output/train',
    labels='inferred',
    batch_size=batch

)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    '../Data/Sport Images/output/val',
    labels='inferred',
    batch_size=batch

)

test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    '../Data/Sport Images/output/test',
    labels='inferred', 
    batch_size=batch,
    shuffle=False
)
# Out:
# Found 2292 files belonging to 5 classes.
# Metal device set to: Apple M1 Pro
# Found 490 files belonging to 5 classes.
# Found 497 files belonging to 5 classes.

# %% [markdown]
# # Data Augmentation

# %%
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomZoom(height_factor=(-0.2, 0.2), width_factor=(-0.2, 0.2)),
    layers.RandomRotation(0.2),
    layers.RandomContrast(0.2),
    layers.RandomTranslation(height_factor=(-0.2, 0.2), width_factor=(-0.2, 0.2))
])


train_ds = train_ds.map(lambda x, y: (data_augmentation(x), y))

# %% [markdown]
# # Transfer learning- ResNet50

# %%
input_shape = (256, 256, 3)
batch_size = batch
num_classes = 5


resnet_model = ResNet50(input_shape=input_shape, include_top=False, weights='imagenet')

for layer in resnet_model.layers:
    layer.trainable = False

x = resnet_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu')(x)
x = Dropout(0.2)(x)
x = BatchNormalization()(x)
predictions = Dense(num_classes, activation='softmax')(x)

resnet50model = Model(inputs=resnet_model.input, outputs=predictions)

resnet50model.compile(optimizer=Adam(learning_rate=0.001),loss='sparse_categorical_crossentropy',metrics=['accuracy'])

early_stop = EarlyStopping(monitor='val_loss',patience = 10, restore_best_weights=True)


history_resnet = resnet50model.fit(train_ds, epochs=50, batch_size=batch, validation_data=val_ds, callbacks=[early_stop])
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/50
# 2023-05-08 14:17:52.382572: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 459/459 [==============================] - 28s 58ms/step - loss: 1.0225 - accuracy: 0.6623 - val_loss: 0.6564 - val_accuracy: 0.7612
# Epoch 2/50
# 459/459 [==============================] - 26s 56ms/step - loss: 0.8200 - accuracy: 0.7090 - val_loss: 0.4642 - val_accuracy: 0.8347
# Epoch 3/50
# 459/459 [==============================] - 26s 56ms/step - loss: 0.7223 - accuracy: 0.7461 - val_loss: 0.4277 - val_accuracy: 0.8408
# Epoch 4/50
# 459/459 [==============================] - 26s 56ms/step - loss: 0.7022 - accuracy: 0.7465 - val_loss: 0.4394 - val_accuracy: 0.8571
# Epoch 5/50
# 459/459 [==============================] - 25s 55ms/step - loss: 0.6971 - accuracy: 0.7496 - val_loss: 0.4801 - val_accuracy: 0.8347
# Epoch 6/50
# 459/459 [==============================] - 26s 56ms/step - loss: 0.6667 - accuracy: 0.7670 - val_loss: 0.3912 - val_accuracy: 0.8531
# Epoch 7/50
# 459/459 [==============================] - 26s 57ms/step - loss: 0.6315 - accuracy: 0.7749 - val_loss: 0.3758 - val_accuracy: 0.8735
# Epoch 8/50
# 459/459 [==============================] - 26s 56ms/step - loss: 0.6164 - accuracy: 0.7832 - val_loss: 0.3644 - val_accuracy: 0.8673
# Epoch 9/50
# 459/459 [==============================] - 26s 56ms/step - loss: 0.6017 - accuracy: 0.7919 - val_loss: 0.3906 - val_accuracy: 0.8510
# Epoch 10/50
# 459/459 [==============================] - 26s 56ms/step - loss: 0.5832 - accuracy: 0.7993 - val_loss: 0.3589 - val_accuracy: 0.8796
# Epoch 11/50
# 459/459 [==============================] - 26s 56ms/step - loss: 0.5793 - accuracy: 0.8006 - val_loss: 0.3711 - val_accuracy: 0.8878
# Epoch 12/50
# 459/459 [==============================] - 26s 56ms/step - loss: 0.5484 - accuracy: 0.8028 - val_loss: 0.3425 - val_accuracy: 0.8878
# Epoch 13/50
# 459/459 [==============================] - 26s 57ms/step - loss: 0.5704 - accuracy: 0.8019 - val_loss: 0.3393 - val_accuracy: 0.8857
# Epoch 14/50
# 459/459 [==============================] - 25s 55ms/step - loss: 0.5688 - accuracy: 0.8041 - val_loss: 0.3251 - val_accuracy: 0.8776
# Epoch 15/50
# 459/459 [==============================] - 25s 55ms/step - loss: 0.5601 - accuracy: 0.7993 - val_loss: 0.2956 - val_accuracy: 0.9061
# Epoch 16/50
# 459/459 [==============================] - 26s 56ms/step - loss: 0.5402 - accuracy: 0.8111 - val_loss: 0.3587 - val_accuracy: 0.8857
# Epoch 17/50
# 459/459 [==============================] - 26s 55ms/step - loss: 0.5173 - accuracy: 0.8172 - val_loss: 0.3549 - val_accuracy: 0.8673
# Epoch 18/50
# 459/459 [==============================] - 26s 56ms/step - loss: 0.5299 - accuracy: 0.8111 - val_loss: 0.3362 - val_accuracy: 0.8735
# Epoch 19/50
# 459/459 [==============================] - 26s 57ms/step - loss: 0.5217 - accuracy: 0.8189 - val_loss: 0.3175 - val_accuracy: 0.8918
# Epoch 20/50
# 459/459 [==============================] - 25s 55ms/step - loss: 0.5070 - accuracy: 0.8159 - val_loss: 0.3763 - val_accuracy: 0.8714
# Epoch 21/50
# 459/459 [==============================] - 26s 56ms/step - loss: 0.4911 - accuracy: 0.8294 - val_loss: 0.3247 - val_accuracy: 0.8939
# Epoch 22/50
# 459/459 [==============================] - 26s 57ms/step - loss: 0.4982 - accuracy: 0.8211 - val_loss: 0.3512 - val_accuracy: 0.8796
# Epoch 23/50
# 459/459 [==============================] - 25s 55ms/step - loss: 0.4605 - accuracy: 0.8351 - val_loss: 0.3490 - val_accuracy: 0.8816
# Epoch 24/50
# 459/459 [==============================] - 26s 56ms/step - loss: 0.4488 - accuracy: 0.8394 - val_loss: 0.3905 - val_accuracy: 0.8633
# Epoch 25/50
# 459/459 [==============================] - 26s 56ms/step - loss: 0.4571 - accuracy: 0.8290 - val_loss: 0.4199 - val_accuracy: 0.8592

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    '../Data/Sport Images/output/train',
    labels='inferred',
    batch_size=batch,
    shuffle=False
)
# Out:
# Found 2292 files belonging to 5 classes.

# %%
plt.plot(history_resnet.history['loss'])
plt.plot(history_resnet.history['val_loss'])
plt.title('Model accuracy')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
# Evaluate on training set
train_pred = resnet50model.predict(train_ds)
train_pred_labels = np.argmax(train_pred, axis=1)
train_true_labels = np.concatenate([y for x, y in train_ds], axis=0)

# Evaluate on test set
test_pred = resnet50model.predict(test_ds)
test_pred_labels = np.argmax(test_pred, axis=1)
test_true_labels = np.concatenate([y for x, y in test_ds], axis=0)

# Calculate evaluation metrics
train_cm = confusion_matrix(train_true_labels, train_pred_labels)
train_cr = classification_report(train_true_labels, train_pred_labels)
train_acc = accuracy_score(train_true_labels, train_pred_labels)
train_f1 = f1_score(train_true_labels, train_pred_labels, average='weighted')

test_cm = confusion_matrix(test_true_labels, test_pred_labels)
test_cr = classification_report(test_true_labels, test_pred_labels)
test_acc = accuracy_score(test_true_labels, test_pred_labels)
test_f1 = f1_score(test_true_labels, test_pred_labels, average='weighted')

print("Evaluation Metrics on Training Set:")
print("Confusion Matrix:\n", train_cm)
print("Classification Report:\n", train_cr)
print("Accuracy: ", train_acc)
print("F1 Score: ", train_f1)

print("\nEvaluation Metrics on Test Set:")
print("Confusion Matrix:\n", test_cm)
print("Classification Report:\n", test_cr)
print("Accuracy: ", test_acc)
print("F1 Score: ", test_f1)
# Out:
# 459/459 [==============================] - 14s 29ms/step
# 100/100 [==============================] - 3s 29ms/step
# Evaluation Metrics on Training Set:
# Confusion Matrix:
#  [[483   8   3  10   9]
#  [  2 331   4   1   6]
#  [  3   2 428   5   5]
#  [  7   5   5 477   6]
#  [  3  17  19   5 448]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.94      0.96       513
#            1       0.91      0.96      0.94       344
#            2       0.93      0.97      0.95       443
#            3       0.96      0.95      0.96       500
#            4       0.95      0.91      0.93       492
#
#     accuracy                           0.95      2292
#    macro avg       0.94      0.95      0.94      2292
# weighted avg       0.95      0.95      0.95      2292
#
# Accuracy:  0.9454624781849913
# F1 Score:  0.9454548690613819
#
# Evaluation Metrics on Test Set:
# Confusion Matrix:
#  [[103   2   2   3   1]
#  [  0  70   2   1   2]
#  [  2   2  87   3   2]
#  [  5   4   1  96   2]
#  [  0   6   4   3  94]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.93      0.93       111
#            1       0.83      0.93      0.88        75
#            2       0.91      0.91      0.91        96
#            3       0.91      0.89      0.90       108
#            4       0.93      0.88      0.90       107
#
#     accuracy                           0.91       497
#    macro avg       0.90      0.91      0.90       497
# weighted avg       0.91      0.91      0.91       497
#
# Accuracy:  0.9054325955734407
# F1 Score:  0.9056590219732267

# %% [markdown]
# # Video Classification - ResNet50

# %%
num_epochs = len(history_resnet.history['loss'])
print("Model ran for {} epochs".format(num_epochs))

test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    '../Data/Sport Images/output/test',
    labels='inferred', 
    batch_size=batch,
    shuffle=True
)

test_val_ds = val_ds.concatenate(test_ds)
test_val_ds = test_val_ds.map(lambda x, y: (data_augmentation(x), y))

resnet50model.fit(test_val_ds, epochs=num_epochs, batch_size=batch)
# Out:
# Model ran for 25 epochs
# Epoch 1/25
# 198/198 [==============================] - 10s 49ms/step - loss: 1.4802 - accuracy: 0.5502
# Epoch 2/25
# 198/198 [==============================] - 10s 49ms/step - loss: 1.4253 - accuracy: 0.4954
# Epoch 3/25
# 198/198 [==============================] - 10s 51ms/step - loss: 1.5862 - accuracy: 0.4438
# Epoch 4/25
# 198/198 [==============================] - 10s 49ms/step - loss: 1.3833 - accuracy: 0.4792
# Epoch 5/25
# 198/198 [==============================] - 10s 49ms/step - loss: 1.4144 - accuracy: 0.4640
# Epoch 6/25
# 198/198 [==============================] - 10s 50ms/step - loss: 1.3314 - accuracy: 0.5147
# Epoch 7/25
# 198/198 [==============================] - 10s 50ms/step - loss: 1.3678 - accuracy: 0.4863
# Epoch 8/25
# 198/198 [==============================] - 10s 50ms/step - loss: 1.2997 - accuracy: 0.5187
# Epoch 9/25
# 198/198 [==============================] - 10s 49ms/step - loss: 1.3397 - accuracy: 0.5137
# Epoch 10/25
# 198/198 [==============================] - 10s 49ms/step - loss: 1.3108 - accuracy: 0.5279
# Epoch 11/25
# 198/198 [==============================] - 10s 49ms/step - loss: 1.3255 - accuracy: 0.4995
# Epoch 12/25
# 198/198 [==============================] - 10s 49ms/step - loss: 1.3056 - accuracy: 0.5046
# Epoch 13/25
# 198/198 [==============================] - 10s 49ms/step - loss: 1.3107 - accuracy: 0.5005
# Epoch 14/25
# 198/198 [==============================] - 10s 49ms/step - loss: 1.3305 - accuracy: 0.5066
# Epoch 15/25
# 198/198 [==============================] - 10s 49ms/step - loss: 1.2815 - accuracy: 0.5187
# Epoch 16/25
# 198/198 [==============================] - 10s 50ms/step - loss: 1.3055 - accuracy: 0.5025
# Epoch 17/25
# 198/198 [==============================] - 10s 49ms/step - loss: 1.2499 - accuracy: 0.5380
# Epoch 18/25
# 198/198 [==============================] - 10s 49ms/step - loss: 1.2839 - accuracy: 0.4995
# Epoch 19/25
# 198/198 [==============================] - 10s 49ms/step - loss: 1.2696 - accuracy: 0.5096
# Epoch 20/25
# 198/198 [==============================] - 10s 50ms/step - loss: 1.2700 - accuracy: 0.5289
# Epoch 21/25
# 198/198 [==============================] - 10s 50ms/step - loss: 1.2811 - accuracy: 0.5228
# Epoch 22/25
# 198/198 [==============================] - 10s 49ms/step - loss: 1.2781 - accuracy: 0.5238
# Epoch 23/25
# 198/198 [==============================] - 10s 49ms/step - loss: 1.2723 - accuracy: 0.5228
# Epoch 24/25
# 198/198 [==============================] - 10s 49ms/step - loss: 1.2320 - accuracy: 0.5390
# Epoch 25/25
# 198/198 [==============================] - 10s 49ms/step - loss: 1.2786 - accuracy: 0.5177

# %% [markdown]
# # Transfer learning- EfficientNet

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    '../Data/Sport Images/output/train',
    labels='inferred',
    batch_size=batch

)
train_ds = train_ds.map(lambda x, y: (data_augmentation(x), y))
# Out:
# Found 2292 files belonging to 5 classes.

# %%
input_shape = (256, 256, 3)
batch_size = batch
num_classes = 5


EfficientNetB0_model = EfficientNetB0(input_shape=input_shape, include_top=False, weights='imagenet')

for layer in EfficientNetB0_model.layers:
    layer.trainable = False

x = EfficientNetB0_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu')(x)
x = Dropout(0.2)(x)
x = BatchNormalization()(x)
predictions = Dense(num_classes, activation='softmax')(x)

EfficientNetmodel = Model(inputs=EfficientNetB0_model.input, outputs=predictions)


EfficientNetmodel.compile(optimizer=Adam(learning_rate=0.001),loss='sparse_categorical_crossentropy',metrics=['accuracy'])

early_stop = EarlyStopping(monitor='val_loss',patience = 10, restore_best_weights=True)


history_EfficientNetmodel = EfficientNetmodel.fit(train_ds, epochs=50, batch_size=batch, validation_data=val_ds, callbacks=[early_stop])
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/50
# 459/459 [==============================] - 27s 53ms/step - loss: 0.9771 - accuracy: 0.6859 - val_loss: 0.2658 - val_accuracy: 0.9082
# Epoch 2/50
# 459/459 [==============================] - 21s 45ms/step - loss: 0.7103 - accuracy: 0.7596 - val_loss: 0.2207 - val_accuracy: 0.9184
# Epoch 3/50
# 459/459 [==============================] - 21s 45ms/step - loss: 0.6779 - accuracy: 0.7692 - val_loss: 0.2081 - val_accuracy: 0.9265
# Epoch 4/50
# 459/459 [==============================] - 21s 46ms/step - loss: 0.6581 - accuracy: 0.7862 - val_loss: 0.2016 - val_accuracy: 0.9184
# Epoch 5/50
# 459/459 [==============================] - 20s 43ms/step - loss: 0.6047 - accuracy: 0.7923 - val_loss: 0.2197 - val_accuracy: 0.9204
# Epoch 6/50
# 459/459 [==============================] - 21s 45ms/step - loss: 0.6186 - accuracy: 0.7984 - val_loss: 0.2082 - val_accuracy: 0.9204
# Epoch 7/50
# 459/459 [==============================] - 21s 45ms/step - loss: 0.5661 - accuracy: 0.8072 - val_loss: 0.1786 - val_accuracy: 0.9347
# Epoch 8/50
# 459/459 [==============================] - 20s 44ms/step - loss: 0.5862 - accuracy: 0.7989 - val_loss: 0.2263 - val_accuracy: 0.9204
# Epoch 9/50
# 459/459 [==============================] - 21s 45ms/step - loss: 0.6046 - accuracy: 0.8002 - val_loss: 0.1681 - val_accuracy: 0.9245
# Epoch 10/50
# 459/459 [==============================] - 20s 44ms/step - loss: 0.5245 - accuracy: 0.8272 - val_loss: 0.2028 - val_accuracy: 0.9265
# Epoch 11/50
# 459/459 [==============================] - 20s 44ms/step - loss: 0.4915 - accuracy: 0.8377 - val_loss: 0.2277 - val_accuracy: 0.9245
# Epoch 12/50
# 459/459 [==============================] - 20s 44ms/step - loss: 0.5101 - accuracy: 0.8233 - val_loss: 0.1913 - val_accuracy: 0.9265
# Epoch 13/50
# 459/459 [==============================] - 21s 45ms/step - loss: 0.5110 - accuracy: 0.8233 - val_loss: 0.1750 - val_accuracy: 0.9286
# Epoch 14/50
# 459/459 [==============================] - 20s 44ms/step - loss: 0.5011 - accuracy: 0.8303 - val_loss: 0.2237 - val_accuracy: 0.9286
# Epoch 15/50
# 459/459 [==============================] - 21s 45ms/step - loss: 0.4727 - accuracy: 0.8316 - val_loss: 0.1665 - val_accuracy: 0.9449
# Epoch 16/50
# 459/459 [==============================] - 20s 44ms/step - loss: 0.5202 - accuracy: 0.8264 - val_loss: 0.1941 - val_accuracy: 0.9388
# Epoch 17/50
# 459/459 [==============================] - 20s 44ms/step - loss: 0.4800 - accuracy: 0.8394 - val_loss: 0.1977 - val_accuracy: 0.9265
# Epoch 18/50
# 459/459 [==============================] - 21s 45ms/step - loss: 0.4388 - accuracy: 0.8455 - val_loss: 0.1812 - val_accuracy: 0.9204
# Epoch 19/50
# 459/459 [==============================] - 21s 45ms/step - loss: 0.4649 - accuracy: 0.8508 - val_loss: 0.1634 - val_accuracy: 0.9388
# Epoch 20/50
# 459/459 [==============================] - 20s 44ms/step - loss: 0.4759 - accuracy: 0.8364 - val_loss: 0.3159 - val_accuracy: 0.9204
# Epoch 21/50
# 459/459 [==============================] - 20s 44ms/step - loss: 0.4830 - accuracy: 0.8333 - val_loss: 0.1723 - val_accuracy: 0.9286
# Epoch 22/50
# 459/459 [==============================] - 20s 44ms/step - loss: 0.4858 - accuracy: 0.8360 - val_loss: 0.1965 - val_accuracy: 0.9224
# Epoch 23/50
# 459/459 [==============================] - 20s 44ms/step - loss: 0.4103 - accuracy: 0.8582 - val_loss: 0.2099 - val_accuracy: 0.9265
# Epoch 24/50
# 459/459 [==============================] - 20s 44ms/step - loss: 0.4009 - accuracy: 0.8626 - val_loss: 0.1662 - val_accuracy: 0.9388
# Epoch 25/50
# 459/459 [==============================] - 20s 44ms/step - loss: 0.4655 - accuracy: 0.8429 - val_loss: 0.2008 - val_accuracy: 0.9286
# Epoch 26/50
# 459/459 [==============================] - 21s 45ms/step - loss: 0.4394 - accuracy: 0.8490 - val_loss: 0.1707 - val_accuracy: 0.9306
# Epoch 27/50
# 459/459 [==============================] - 20s 43ms/step - loss: 0.4446 - accuracy: 0.8517 - val_loss: 0.1878 - val_accuracy: 0.9327
# Epoch 28/50
# 459/459 [==============================] - 21s 46ms/step - loss: 0.4523 - accuracy: 0.8486 - val_loss: 0.1587 - val_accuracy: 0.9531
# Epoch 29/50
# 459/459 [==============================] - 21s 46ms/step - loss: 0.4201 - accuracy: 0.8630 - val_loss: 0.1729 - val_accuracy: 0.9286
# Epoch 30/50
# 459/459 [==============================] - 21s 45ms/step - loss: 0.4153 - accuracy: 0.8517 - val_loss: 0.1732 - val_accuracy: 0.9388
# Epoch 31/50
# 459/459 [==============================] - 20s 44ms/step - loss: 0.4386 - accuracy: 0.8508 - val_loss: 0.1642 - val_accuracy: 0.9429
# Epoch 32/50
# 459/459 [==============================] - 20s 44ms/step - loss: 0.4389 - accuracy: 0.8486 - val_loss: 0.1754 - val_accuracy: 0.9408
# Epoch 33/50
# 459/459 [==============================] - 21s 45ms/step - loss: 0.4062 - accuracy: 0.8595 - val_loss: 0.1649 - val_accuracy: 0.9286
# Epoch 34/50
# 459/459 [==============================] - 20s 44ms/step - loss: 0.4109 - accuracy: 0.8621 - val_loss: 0.1791 - val_accuracy: 0.9204
# Epoch 35/50
# 459/459 [==============================] - 20s 44ms/step - loss: 0.4434 - accuracy: 0.8525 - val_loss: 0.1959 - val_accuracy: 0.9347
# Epoch 36/50
# 459/459 [==============================] - 21s 45ms/step - loss: 0.4080 - accuracy: 0.8547 - val_loss: 0.2578 - val_accuracy: 0.9122
# Epoch 37/50
# 459/459 [==============================] - 20s 44ms/step - loss: 0.4166 - accuracy: 0.8617 - val_loss: 0.1867 - val_accuracy: 0.9347
# Epoch 38/50
# 459/459 [==============================] - 20s 44ms/step - loss: 0.4021 - accuracy: 0.8565 - val_loss: 0.2236 - val_accuracy: 0.9265

# %%
plt.plot(history_EfficientNetmodel.history['loss'])
plt.plot(history_EfficientNetmodel.history['val_loss'])
plt.title('Model accuracy')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    '../Data/Sport Images/output/train',
    labels='inferred',
    batch_size=batch,
    shuffle=False
)
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    '../Data/Sport Images/output/test',
    labels='inferred', 
    batch_size=batch,
    shuffle=False
)
# Out:
# Found 2292 files belonging to 5 classes.

# %%
from sklearn.metrics import confusion_matrix, classification_report,accuracy_score,f1_score

# Evaluate on training set
train_pred = EfficientNetmodel.predict(train_ds)
train_pred_labels = np.argmax(train_pred, axis=1)
train_true_labels = np.concatenate([y for x, y in train_ds], axis=0)

# Evaluate on test set
test_pred = EfficientNetmodel.predict(test_ds)
test_pred_labels = np.argmax(test_pred, axis=1)
test_true_labels = np.concatenate([y for x, y in test_ds], axis=0)

# Calculate evaluation metrics
train_cm = confusion_matrix(train_true_labels, train_pred_labels)
train_cr = classification_report(train_true_labels, train_pred_labels)
train_acc = accuracy_score(train_true_labels, train_pred_labels)
train_f1 = f1_score(train_true_labels, train_pred_labels, average='weighted')

test_cm = confusion_matrix(test_true_labels, test_pred_labels)
test_cr = classification_report(test_true_labels, test_pred_labels)
test_acc = accuracy_score(test_true_labels, test_pred_labels)
test_f1 = f1_score(test_true_labels, test_pred_labels, average='weighted')

print("Evaluation Metrics on Training Set:")
print("Confusion Matrix:\n", train_cm)
print("Classification Report:\n", train_cr)
print("Accuracy: ", train_acc)
print("F1 Score: ", train_f1)

print("\nEvaluation Metrics on Test Set:")
print("Confusion Matrix:\n", test_cm)
print("Classification Report:\n", test_cr)
print("Accuracy: ", test_acc)
print("F1 Score: ", test_f1)
# Out:
# 459/459 [==============================] - 12s 23ms/step
# 100/100 [==============================] - 2s 23ms/step
# Evaluation Metrics on Training Set:
# Confusion Matrix:
#  [[505   0   6   2   0]
#  [  1 331   2   4   6]
#  [  2   0 440   1   0]
#  [  4   5   4 486   1]
#  [  2   5   9   4 472]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       513
#            1       0.97      0.96      0.97       344
#            2       0.95      0.99      0.97       443
#            3       0.98      0.97      0.97       500
#            4       0.99      0.96      0.97       492
#
#     accuracy                           0.97      2292
#    macro avg       0.97      0.97      0.97      2292
# weighted avg       0.97      0.97      0.97      2292
#
# Accuracy:  0.974694589877836
# F1 Score:  0.9746852073652125
#
# Evaluation Metrics on Test Set:
# Confusion Matrix:
#  [[108   0   1   1   1]
#  [  0  74   0   0   1]
#  [  2   1  91   1   1]
#  [  4   2   0 100   2]
#  [  0   2   2   3 100]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.97      0.96       111
#            1       0.94      0.99      0.96        75
#            2       0.97      0.95      0.96        96
#            3       0.95      0.93      0.94       108
#            4       0.95      0.93      0.94       107
#
#     accuracy                           0.95       497
#    macro avg       0.95      0.95      0.95       497
# weighted avg       0.95      0.95      0.95       497
#
# Accuracy:  0.9517102615694165
# F1 Score:  0.9516049572342145

# %% [markdown]
# # Video Classification - EfficientNet

# %%
num_epochs = len(history_EfficientNetmodel.history['loss'])
print("Model ran for {} epochs".format(num_epochs))


EfficientNetmodel.fit(test_val_ds, epochs=num_epochs, batch_size=batch)
# Out:
# Model ran for 38 epochs
# Epoch 1/38
# 198/198 [==============================] - 8s 40ms/step - loss: 1.6295 - accuracy: 0.5390
# Epoch 2/38
# 198/198 [==============================] - 8s 39ms/step - loss: 1.5301 - accuracy: 0.4954
# Epoch 3/38
# 198/198 [==============================] - 8s 39ms/step - loss: 1.4629 - accuracy: 0.4873
# Epoch 4/38
# 198/198 [==============================] - 8s 39ms/step - loss: 1.4171 - accuracy: 0.4853
# Epoch 5/38
# 198/198 [==============================] - 8s 39ms/step - loss: 1.3674 - accuracy: 0.5218
# Epoch 6/38
# 198/198 [==============================] - 8s 40ms/step - loss: 1.3366 - accuracy: 0.5279
# Epoch 7/38
# 198/198 [==============================] - 8s 40ms/step - loss: 1.3005 - accuracy: 0.5370
# Epoch 8/38
# 198/198 [==============================] - 8s 40ms/step - loss: 1.3354 - accuracy: 0.5289
# Epoch 9/38
# 198/198 [==============================] - 8s 40ms/step - loss: 1.3213 - accuracy: 0.5218
# Epoch 10/38
# 198/198 [==============================] - 8s 40ms/step - loss: 1.3097 - accuracy: 0.5350
# Epoch 11/38
# 198/198 [==============================] - 8s 40ms/step - loss: 1.3176 - accuracy: 0.5147
# Epoch 12/38
# 198/198 [==============================] - 8s 40ms/step - loss: 1.2920 - accuracy: 0.5339
# Epoch 13/38
# 198/198 [==============================] - 8s 40ms/step - loss: 1.2931 - accuracy: 0.5491
# Epoch 14/38
# 198/198 [==============================] - 8s 40ms/step - loss: 1.2870 - accuracy: 0.5289
# Epoch 15/38
# 198/198 [==============================] - 8s 40ms/step - loss: 1.2708 - accuracy: 0.5512
# Epoch 16/38
# 198/198 [==============================] - 8s 40ms/step - loss: 1.2913 - accuracy: 0.5451
# Epoch 17/38
# 198/198 [==============================] - 8s 40ms/step - loss: 1.2831 - accuracy: 0.5329
# Epoch 18/38
# 198/198 [==============================] - 8s 40ms/step - loss: 1.2639 - accuracy: 0.5512
# Epoch 19/38
# 198/198 [==============================] - 8s 40ms/step - loss: 1.2718 - accuracy: 0.5238
# Epoch 20/38
# 198/198 [==============================] - 8s 40ms/step - loss: 1.2623 - accuracy: 0.5360
# Epoch 21/38
# 198/198 [==============================] - 8s 40ms/step - loss: 1.2594 - accuracy: 0.5410
# Epoch 22/38
# 198/198 [==============================] - 8s 40ms/step - loss: 1.2322 - accuracy: 0.5562
# Epoch 23/38
# 198/198 [==============================] - 8s 40ms/step - loss: 1.2532 - accuracy: 0.5461
# Epoch 24/38
# 198/198 [==============================] - 8s 40ms/step - loss: 1.2564 - accuracy: 0.5339
# Epoch 25/38
# 198/198 [==============================] - 8s 40ms/step - loss: 1.2512 - accuracy: 0.5461
# Epoch 26/38
# 198/198 [==============================] - 8s 40ms/step - loss: 1.2568 - accuracy: 0.5583
# Epoch 27/38
# 198/198 [==============================] - 8s 40ms/step - loss: 1.2450 - accuracy: 0.5400
# Epoch 28/38
# 198/198 [==============================] - 8s 40ms/step - loss: 1.2493 - accuracy: 0.5603
# Epoch 29/38
# 198/198 [==============================] - 8s 40ms/step - loss: 1.2498 - accuracy: 0.5502
# Epoch 30/38
# 198/198 [==============================] - 8s 40ms/step - loss: 1.2272 - accuracy: 0.5461
# Epoch 31/38
# 198/198 [==============================] - 8s 42ms/step - loss: 1.2523 - accuracy: 0.5613
# Epoch 32/38
# 198/198 [==============================] - 8s 40ms/step - loss: 1.2486 - accuracy: 0.5532
# Epoch 33/38
# 198/198 [==============================] - 8s 40ms/step - loss: 1.2447 - accuracy: 0.5583
# Epoch 34/38
# 198/198 [==============================] - 8s 40ms/step - loss: 1.2451 - accuracy: 0.5481
# Epoch 35/38
# 198/198 [==============================] - 8s 40ms/step - loss: 1.2324 - accuracy: 0.5633
# Epoch 36/38
# 198/198 [==============================] - 8s 40ms/step - loss: 1.2247 - accuracy: 0.5562
# Epoch 37/38
# 198/198 [==============================] - 8s 40ms/step - loss: 1.2310 - accuracy: 0.5552
# Epoch 38/38
# 198/198 [==============================] - 8s 41ms/step - loss: 1.2264 - accuracy: 0.5400

# %% [markdown]
# # Transfer learning- VGG16

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    '../Data/Sport Images/output/train',
    labels='inferred',
    batch_size=batch

)
train_ds = train_ds.map(lambda x, y: (data_augmentation(x), y))
# Out:
# Found 2292 files belonging to 5 classes.

# %%
input_shape = (256, 256, 3)
batch_size = 5
num_classes = 5


VGG16_model = VGG16(input_shape=input_shape, include_top=False, weights='imagenet')

for layer in VGG16_model.layers:
    layer.trainable = False


x = VGG16_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(1024, activation='relu')(x)
x = Dropout(0.2)(x)
x = BatchNormalization()(x)
predictions = Dense(num_classes, activation='softmax')(x)

VGGmodel = Model(inputs=VGG16_model.input, outputs=predictions)


VGGmodel.compile(optimizer=Adam(learning_rate=0.001),loss='sparse_categorical_crossentropy',metrics=['accuracy'])

early_stop = EarlyStopping(monitor='val_loss',patience = 10, restore_best_weights=True)


history_VGGmodel = VGGmodel.fit(train_ds, epochs=50, batch_size=batch, validation_data=val_ds, callbacks=[early_stop])
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/50
# 459/459 [==============================] - 43s 93ms/step - loss: 1.1003 - accuracy: 0.6230 - val_loss: 0.8541 - val_accuracy: 0.7755
# Epoch 2/50
# 459/459 [==============================] - 42s 91ms/step - loss: 0.8955 - accuracy: 0.6784 - val_loss: 0.7283 - val_accuracy: 0.7959
# Epoch 3/50
# 459/459 [==============================] - 42s 91ms/step - loss: 0.8433 - accuracy: 0.6972 - val_loss: 0.5999 - val_accuracy: 0.8286
# Epoch 4/50
# 459/459 [==============================] - 42s 91ms/step - loss: 0.7913 - accuracy: 0.7072 - val_loss: 0.5048 - val_accuracy: 0.8429
# Epoch 5/50
# 459/459 [==============================] - 42s 91ms/step - loss: 0.7831 - accuracy: 0.7203 - val_loss: 0.5888 - val_accuracy: 0.8061
# Epoch 6/50
# 459/459 [==============================] - 42s 91ms/step - loss: 0.7730 - accuracy: 0.7229 - val_loss: 0.5529 - val_accuracy: 0.8245
# Epoch 7/50
# 459/459 [==============================] - 42s 91ms/step - loss: 0.7414 - accuracy: 0.7356 - val_loss: 0.6164 - val_accuracy: 0.8163
# Epoch 8/50
# 459/459 [==============================] - 42s 91ms/step - loss: 0.7322 - accuracy: 0.7413 - val_loss: 0.4600 - val_accuracy: 0.8327
# Epoch 9/50
# 459/459 [==============================] - 42s 91ms/step - loss: 0.7278 - accuracy: 0.7247 - val_loss: 0.4766 - val_accuracy: 0.8388
# Epoch 10/50
# 459/459 [==============================] - 42s 91ms/step - loss: 0.7653 - accuracy: 0.7299 - val_loss: 0.5068 - val_accuracy: 0.8388
# Epoch 11/50
# 459/459 [==============================] - 42s 91ms/step - loss: 0.7275 - accuracy: 0.7343 - val_loss: 0.4855 - val_accuracy: 0.8551
# Epoch 12/50
# 459/459 [==============================] - 42s 91ms/step - loss: 0.7250 - accuracy: 0.7439 - val_loss: 0.4309 - val_accuracy: 0.8612
# Epoch 13/50
# 459/459 [==============================] - 42s 91ms/step - loss: 0.6861 - accuracy: 0.7539 - val_loss: 0.4247 - val_accuracy: 0.8694
# Epoch 14/50
# 459/459 [==============================] - 42s 92ms/step - loss: 0.6859 - accuracy: 0.7561 - val_loss: 0.5574 - val_accuracy: 0.8082
# Epoch 15/50
# 459/459 [==============================] - 42s 92ms/step - loss: 0.6885 - accuracy: 0.7531 - val_loss: 0.4542 - val_accuracy: 0.8551
# Epoch 16/50
# 459/459 [==============================] - 42s 91ms/step - loss: 0.6573 - accuracy: 0.7640 - val_loss: 0.6318 - val_accuracy: 0.8163
# Epoch 17/50
# 459/459 [==============================] - 42s 91ms/step - loss: 0.6516 - accuracy: 0.7587 - val_loss: 0.4935 - val_accuracy: 0.8286
# Epoch 18/50
# 459/459 [==============================] - 42s 91ms/step - loss: 0.6476 - accuracy: 0.7627 - val_loss: 0.5392 - val_accuracy: 0.8327
# Epoch 19/50
# 459/459 [==============================] - 42s 91ms/step - loss: 0.6490 - accuracy: 0.7723 - val_loss: 0.5845 - val_accuracy: 0.8224
# Epoch 20/50
# 459/459 [==============================] - 42s 91ms/step - loss: 0.6555 - accuracy: 0.7683 - val_loss: 0.5241 - val_accuracy: 0.8306
# Epoch 21/50
# 459/459 [==============================] - 42s 91ms/step - loss: 0.6034 - accuracy: 0.7810 - val_loss: 0.6311 - val_accuracy: 0.8347
# Epoch 22/50
# 459/459 [==============================] - 42s 92ms/step - loss: 0.6650 - accuracy: 0.7609 - val_loss: 0.6340 - val_accuracy: 0.8286
# Epoch 23/50
# 459/459 [==============================] - 42s 91ms/step - loss: 0.6408 - accuracy: 0.7723 - val_loss: 0.4765 - val_accuracy: 0.8469

# %%
plt.plot(history_VGGmodel.history['loss'])
plt.plot(history_VGGmodel.history['val_loss'])
plt.title('Model accuracy')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    '../Data/Sport Images/output/train',
    labels='inferred',
    batch_size=batch,
    shuffle=False
)
# Out:
# Found 2292 files belonging to 5 classes.

# %%
from sklearn.metrics import confusion_matrix, classification_report,accuracy_score,f1_score

# Evaluate on training set
train_pred = VGGmodel.predict(train_ds)
train_pred_labels = np.argmax(train_pred, axis=1)
train_true_labels = np.concatenate([y for x, y in train_ds], axis=0)

# Evaluate on test set
test_pred = VGGmodel.predict(test_ds)
test_pred_labels = np.argmax(test_pred, axis=1)
test_true_labels = np.concatenate([y for x, y in test_ds], axis=0)

# Calculate evaluation metrics
train_cm = confusion_matrix(train_true_labels, train_pred_labels)
train_cr = classification_report(train_true_labels, train_pred_labels)
train_acc = accuracy_score(train_true_labels, train_pred_labels)
train_f1 = f1_score(train_true_labels, train_pred_labels, average='weighted')

test_cm = confusion_matrix(test_true_labels, test_pred_labels)
test_cr = classification_report(test_true_labels, test_pred_labels)
test_acc = accuracy_score(test_true_labels, test_pred_labels)
test_f1 = f1_score(test_true_labels, test_pred_labels, average='weighted')

print("Evaluation Metrics on Training Set:")
print("Confusion Matrix:\n", train_cm)
print("Classification Report:\n", train_cr)
print("Accuracy: ", train_acc)
print("F1 Score: ", train_f1)

print("\nEvaluation Metrics on Test Set:")
print("Confusion Matrix:\n", test_cm)
print("Classification Report:\n", test_cr)
print("Accuracy: ", test_acc)
print("F1 Score: ", test_f1)
# Out:
# 459/459 [==============================] - 23s 49ms/step
# 100/100 [==============================] - 5s 49ms/step
# Evaluation Metrics on Training Set:
# Confusion Matrix:
#  [[456  16   9  24   8]
#  [  8 303   6   7  20]
#  [ 11   3 391  30   8]
#  [ 10  10   1 473   6]
#  [ 10  13  10  34 425]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.89      0.90       513
#            1       0.88      0.88      0.88       344
#            2       0.94      0.88      0.91       443
#            3       0.83      0.95      0.89       500
#            4       0.91      0.86      0.89       492
#
#     accuracy                           0.89      2292
#    macro avg       0.90      0.89      0.89      2292
# weighted avg       0.90      0.89      0.89      2292
#
# Accuracy:  0.893542757417103
# F1 Score:  0.8937553071313465
#
# Evaluation Metrics on Test Set:
# Confusion Matrix:
#  [[94  5  2  5  5]
#  [ 1 62  1  2  9]
#  [ 5  1 81  8  1]
#  [ 8  2  0 96  2]
#  [ 0  3  3 11 90]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.87      0.85      0.86       111
#            1       0.85      0.83      0.84        75
#            2       0.93      0.84      0.89        96
#            3       0.79      0.89      0.83       108
#            4       0.84      0.84      0.84       107
#
#     accuracy                           0.85       497
#    macro avg       0.86      0.85      0.85       497
# weighted avg       0.85      0.85      0.85       497
#
# Accuracy:  0.8511066398390342
# F1 Score:  0.8516411214632235

# %% [markdown]
# # Video Classification - EfficientNet

# %%
num_epochs = len(history_VGGmodel.history['loss'])
print("Model ran for {} epochs".format(num_epochs))


VGGmodel.fit(test_val_ds, epochs=num_epochs, batch_size=batch)
# Out:
# Model ran for 23 epochs
# Epoch 1/23
# 198/198 [==============================] - 16s 81ms/step - loss: 1.5289 - accuracy: 0.5370
# Epoch 2/23
# 198/198 [==============================] - 16s 80ms/step - loss: 1.4696 - accuracy: 0.4813
# Epoch 3/23
# 198/198 [==============================] - 16s 80ms/step - loss: 1.6386 - accuracy: 0.4154
# Epoch 4/23
# 198/198 [==============================] - 16s 80ms/step - loss: 1.4444 - accuracy: 0.4448
# Epoch 5/23
# 198/198 [==============================] - 16s 80ms/step - loss: 1.4460 - accuracy: 0.4357
# Epoch 6/23
# 198/198 [==============================] - 16s 80ms/step - loss: 1.4606 - accuracy: 0.4417
# Epoch 7/23
# 198/198 [==============================] - 16s 80ms/step - loss: 1.4065 - accuracy: 0.4843
# Epoch 8/23
# 198/198 [==============================] - 16s 80ms/step - loss: 1.4035 - accuracy: 0.4600
# Epoch 9/23
# 198/198 [==============================] - 16s 80ms/step - loss: 1.4034 - accuracy: 0.4681
# Epoch 10/23
# 198/198 [==============================] - 16s 80ms/step - loss: 1.3851 - accuracy: 0.4873
# Epoch 11/23
# 198/198 [==============================] - 16s 80ms/step - loss: 1.4057 - accuracy: 0.4742
# Epoch 12/23
# 198/198 [==============================] - 16s 81ms/step - loss: 1.3815 - accuracy: 0.4661
# Epoch 13/23
# 198/198 [==============================] - 16s 80ms/step - loss: 1.3772 - accuracy: 0.4671
# Epoch 14/23
# 198/198 [==============================] - 16s 80ms/step - loss: 1.3925 - accuracy: 0.4640
# Epoch 15/23
# 198/198 [==============================] - 16s 80ms/step - loss: 1.3747 - accuracy: 0.4539
# Epoch 16/23
# 198/198 [==============================] - 16s 80ms/step - loss: 1.4116 - accuracy: 0.4326
# Epoch 17/23
# 198/198 [==============================] - 16s 81ms/step - loss: 1.3703 - accuracy: 0.4681
# Epoch 18/23
# 198/198 [==============================] - 16s 80ms/step - loss: 1.3901 - accuracy: 0.4701
# Epoch 19/23
# 198/198 [==============================] - 16s 80ms/step - loss: 1.3721 - accuracy: 0.4863
# Epoch 20/23
# 198/198 [==============================] - 16s 80ms/step - loss: 1.3696 - accuracy: 0.4752
# Epoch 21/23
# 198/198 [==============================] - 16s 80ms/step - loss: 1.3784 - accuracy: 0.4691
# Epoch 22/23
# 198/198 [==============================] - 16s 81ms/step - loss: 1.3638 - accuracy: 0.4802
# Epoch 23/23
# 198/198 [==============================] - 16s 80ms/step - loss: 1.3495 - accuracy: 0.4985

# %%
from tensorflow.keras.preprocessing.image import img_to_array
import statistics

class_names = {'BaseballPitch':0, 'Basketball':1, 'Fencing':2, 'TennisSwing':3, 'VolleyballSpiking':4}
true_labels = []
predictions1 = []
predictions2 = []
predictions3 = []
avg_predictions1 = []
avg_predictions2 = []
avg_predictions3 = []
num_predictions = 0
video_path = '../Data/Sport Videos'

for dir_path in os.listdir(video_path):
    if not os.path.basename(dir_path).startswith('.'):
        sub_path = os.path.join(video_path,dir_path)

        for filename in os.listdir(sub_path):
            true_label = class_names[dir_path]
            true_labels.append(true_label) 
            video = cv2.VideoCapture(os.path.join(sub_path,filename))
            num_frames = int(video.get(cv2.CAP_PROP_FRAME_COUNT))
            probabilities1 = []
            probabilities2 = []
            probabilities3 = []
#             stride = max(num_frames // 100, 1)
#             count = 0
            for frame_num in range(0, num_frames, 50):
#                 if count >100:
#                     break
                # Set the video's current frame position
                video.set(cv2.CAP_PROP_POS_FRAMES, frame_num)

                # Read the frame at the current position
                ret, frame = video.read()
                if not ret:
                    continue
                frame = cv2.cvtColor(frame,cv2.COLOR_BGR2RGB)
                frame = cv2.resize(frame, (256, 256))
                frame = img_to_array(frame)
                frame = np.expand_dims(frame, axis=0)
                
                prediction1 = resnet50model.predict(frame)
                prediction2 = EfficientNetmodel.predict(frame)
                prediction3 = VGGmodel.predict(frame)
                probabilities1.append(prediction1)
                probabilities2.append(prediction2)
                probabilities3.append(prediction3)
#                 count += 1

            avg_prediction1 = np.mean(probabilities1, axis=0) 
            avg_predictions1.append(avg_prediction1) 
        
            avg_prediction2 = np.mean(probabilities2, axis=0) 
            avg_predictions2.append(avg_prediction2) 
            
            avg_prediction3 = np.mean(probabilities3, axis=0) 
            avg_predictions3.append(avg_prediction3)
# Out:
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 201ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# ...
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 15ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 13ms/step

# %%
# Convert the true labels and predictions to numpy arrays
true_labels = np.array(true_labels)
predictions1 = np.argmax(np.concatenate(avg_predictions1, axis=0), axis=1)

# Calculate the confusion matrix, precision, recall, accuracy, and F1 score
conf_mat = confusion_matrix(true_labels, predictions1)
cr = classification_report(true_labels, predictions1)
acc = accuracy_score(true_labels, predictions1)
f1 = f1_score(true_labels, predictions1, average='weighted')
print("Model : ResNet50")
print("Confusion Matrix:\n", conf_mat)
print("Classification Report:\n", cr)
print("Accuracy: ", acc)
print("F1 Score: ", f1)



predictions2 = np.argmax(np.concatenate(avg_predictions2, axis=0), axis=1)

# Calculate the confusion matrix, precision, recall, accuracy, and F1 score
conf_mat = confusion_matrix(true_labels, predictions2)
cr = classification_report(true_labels, predictions2)
acc = accuracy_score(true_labels, predictions2)
f1 = f1_score(true_labels, predictions2, average='weighted')
print("\nModel : EfficeintNet")
print("Confusion Matrix:\n", conf_mat)
print("Classification Report:\n", cr)
print("Accuracy: ", acc)
print("F1 Score: ", f1)


predictions3 = np.argmax(np.concatenate(avg_predictions3, axis=0), axis=1)

# Calculate the confusion matrix, precision, recall, accuracy, and F1 score
conf_mat = confusion_matrix(true_labels, predictions3)
cr = classification_report(true_labels, predictions3)
acc = accuracy_score(true_labels, predictions3)
f1 = f1_score(true_labels, predictions3, average='weighted')
print("\nModel : VGG16")
print("Confusion Matrix:\n", conf_mat)
print("Classification Report:\n", cr)
print("Accuracy: ", acc)
print("F1 Score: ", f1)
# Out:
# Model : ResNet50
# Confusion Matrix:
#  [[ 91   1   2  49   7]
#  [  2   8  46  74   7]
#  [  1   0 103   5   2]
#  [  0   0  12 155   0]
#  [  0   0  84   8  24]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.61      0.75       150
#            1       0.89      0.06      0.11       137
#            2       0.42      0.93      0.58       111
#            3       0.53      0.93      0.68       167
#            4       0.60      0.21      0.31       116
#
#     accuracy                           0.56       681
#    macro avg       0.68      0.55      0.48       681
# weighted avg       0.69      0.56      0.50       681
#
# Accuracy:  0.5594713656387665
# F1 Score:  0.498528186639925
# Model : EfficeintNet
# Confusion Matrix:
#  [[130   0   2  15   3]
#  [  8   0  67  41  21]
#  [  7   0  91  11   2]
#  [ 19   0  10 138   0]
#  [  0   0  78   5  33]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.79      0.87      0.83       150
#            1       0.00      0.00      0.00       137
#            2       0.37      0.82      0.51       111
#            3       0.66      0.83      0.73       167
#            4       0.56      0.28      0.38       116
#
#     accuracy                           0.58       681
#    macro avg       0.48      0.56      0.49       681
# weighted avg       0.49      0.58      0.51       681
#
# Accuracy:  0.5756240822320118
# F1 Score:  0.5087890169392324
# Model : VGG16
# Confusion Matrix:
#  [[117   0   9   9  15]
#  [ 18   1  29  50  39]
#  [ 14   0  95   0   2]
#  [ 42   4   3  97  21]
#  [  4   1  75   6  30]]
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.60      0.78      0.68       150
#            1       0.17      0.01      0.01       137
#            2       0.45      0.86      0.59       111
#            3       0.60      0.58      0.59       167
#            4       0.28      0.26      0.27       116
#
#     accuracy                           0.50       681
#    macro avg       0.42      0.50      0.43       681
# weighted avg       0.43      0.50      0.44       681
#
# Accuracy:  0.49926578560939794
# F1 Score:  0.4388209034161257
